# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv('/Car details v3.csv')

# %% [markdown]
# # Data Exploring

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
df.nunique()
# Out:
# name             2058
# year               29
# selling_price     677
# km_driven         921
# fuel                4
# seller_type         3
# transmission        2
# owner               5
# mileage           393
# engine            121
# max_power         322
# torque            441
# seats               9
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df = df.drop('name',axis=1)

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
#
#           owner     mileage   engine   max_power                    torque  \
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp            190Nm@ 2000rpm
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm
# 2   Third Owner   17.7 kmpl  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)
# 3   First Owner   23.0 kmpl  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm
# 4   First Owner   16.1 kmpl  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['seller_type'] = le.fit_transform(df['seller_type'])
df['owner'] = le.fit_transform(df['owner'])
df['fuel'] = le.fit_transform(df['fuel'])
df['transmission'] = le.fit_transform(df['transmission'])

# %%
df['mileage'] = df['mileage'].str.replace('kmpl','', regex=True)
df['mileage'] = df['mileage'].str.replace('km/kg','', regex=True)
df['mileage']
# Out:
# 0        23.4
# 1       21.14
# 2        17.7
# 3        23.0
# 4        16.1
#          ...
# 8123     18.5
# 8124     16.8
# 8125     19.3
# 8126    23.57
# 8127    23.57
# Name: mileage, Length: 7906, dtype: object

# %%
df['engine'] = df['engine'].str.replace('CC','', regex=True)
sns.distplot(df['engine'])
# Out:
# <ipython-input-28-e97f1c7d7a68>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['engine'])
# <Axes: xlabel='engine', ylabel='Density'>

# %%
df['max_power'] = df['max_power'].str.replace('[a-z]','', regex=True)
plt.hist(df['max_power'])
# Out:
# (array([2495., 1551.,  976., 1360.,  688.,  354.,  246.,  119.,   71.,
#           46.]),
#  array([  0. ,  31.9,  63.8,  95.7, 127.6, 159.5, 191.4, 223.3, 255.2,
#         287.1, 319. ]),
#  <BarContainer object of 10 artists>)

# %%
df['torque'].dropna().head(20)
# Out:
# 0               190Nm@ 2000rpm
# 1          250Nm@ 1500-2500rpm
# 2        12.7@ 2,700(kgm@ rpm)
# 3     22.4 kgm at 1750-2750rpm
# 4        11.5@ 4,500(kgm@ rpm)
# 5            113.75nm@ 4000rpm
# 6         7.8@ 4,500(kgm@ rpm)
# 7                59Nm@ 2500rpm
# 8          170Nm@ 1800-2400rpm
# 9               160Nm@ 2000rpm
# 10              248Nm@ 2250rpm
# 11               78Nm@ 4500rpm
# 12              190Nm@ 2000rpm
# 14               84Nm@ 3500rpm
# 15         115Nm@ 3500-3600rpm
# 16              200Nm@ 1750rpm
# 17    22.4 kgm at 1750-2750rpm
# 18               62Nm@ 3000rpm
# 19       219.7Nm@ 1500-2750rpm
# 20              160Nm@ 2000rpm
# Name: torque, dtype: object

# %%
def list_value_counts(df, origin_cols):
    for name in origin_cols:
        print(f"<======= {name} =======>")
        print(df[name].value_counts())
        print()

# %%
def clear_val_unit_cols(df, cols):
    data = df.copy()
    for name in cols:
        data = data.astype({name+'_val':float})
        # take first value from ..._unit column to add unit as postfix for names of ..._val columns
        data = data.rename(columns={name+'_val' : name+'_'+str.lower(data[name+'_unit'][0])})
        data = data.drop(columns = [name, name+'_unit'])

    return data

# %%
import re
/ 1900
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def split_torque(row):
    """
    Splits 'torque' value in a row and creates 4 new fields:
    > 'torque_val' - value of car max torque;
    > 'torque_unit' - unit of value in 'torque_val';
    > 'torque_eng_sp_val' - value of engine speed at which car max torque is reached;
    > 'torque_eng_sp_unit' - unit of value in 'torque_eng_sp_val';
    """
    torque_val, torque_unit, torque_eng_sp_val, torque_eng_sp_unit = np.nan, np.nan, np.nan, np.nan

    # skip null values
    if row['torque'] is np.nan:
        return torque_val, torque_unit, torque_eng_sp_val, torque_eng_sp_unit

    # clear torque value from ',' and tailing ')', split and save in temporary list
    temp = re.split(
        '\(11.2\)@ |\(38.7kgm\)@ |\+\/-500r|\+\/-500\(N|  N| N| r|N|@ r|@ |  r|r|\(k|\(| at |n|-|~| k|k| \/ | \/|\s',
        str(row['torque']).replace(',','').strip(' \)')
    )

    # first element of split should be number, helps find cases that should be added in the logic of code
    if is_number(temp[0]):
        torque_val = float(temp[0])
    else:
        print('>>> Error_1:', temp, '\n\n', row, '\n\n\n')

    try:
        if is_number(temp[1]):
            torque_eng_sp_val = float(temp[1])
            if len(temp) == 2:
                torque_unit = 'Nm'
                torque_eng_sp_unit = 'rpm'
            elif len(temp) > 2:
                if is_number(temp[2]):
                    torque_eng_sp_val = (float(temp[1])+float(temp[2]))/2
                    torque_unit = 'Nm'
                    torque_eng_sp_unit = 'rpm'
                else:
                    torque_unit = temp[2]
                    torque_eng_sp_unit = temp[3]
        elif len(temp) == 2:
            torque_unit = temp[1]
        elif len(temp) == 3:
            torque_unit = temp[1]
            torque_eng_sp_val = float(temp[2])
            torque_eng_sp_unit = 'rpm'
        elif len(temp) == 4:
            if is_number(temp[3]):
                torque_eng_sp_val = (float(temp[2])+float(temp[3]))/2
                torque_eng_sp_unit = 'rpm'
                torque_unit = temp[1]
            else:
                torque_unit = temp[1]
                torque_eng_sp_val = float(temp[2])
                torque_eng_sp_unit = temp[3]
        elif len(temp) == 5:
            torque_unit = temp[1]
            torque_eng_sp_val = (float(temp[2])+float(temp[3]))/2
            torque_eng_sp_unit = temp[4]
        # else statement helps find cases that should be added in the logic of code
        else:
            print('>>> Error_2:', temp, '\n\n', row, '\n\n\n')

        return torque_val, torque_unit, torque_eng_sp_val, torque_eng_sp_unit
    # in case some error is raised during assigning new values, helps find cases that should be added in the logic of code
    except:
        print('>>> Error_3:', temp, '\n\n', row, '\n\n\n')

def parse_torque(df):
    data = df.copy()

    # split torque
    torque_new_cols = ['torque_val', 'torque_unit', 'torque_eng_sp_val', 'torque_eng_sp_unit']
    data[torque_new_cols] = data.apply(split_torque, axis=1, result_type="expand")

    # fix units after spliting
    data['torque_unit'] = data['torque_unit'].replace({
        'm': 'nm',
        'gm': 'kgm',
        'Nm': 'nm',
        'KGM': 'kgm',
        'M': 'nm'
    })
    data['torque_eng_sp_unit'] = data['torque_eng_sp_unit'].replace({
        'pm': 'rpm',
        'RPM': 'rpm'
    })

    return data

# %%
df = parse_torque(df)
df[['torque', 'torque_val', 'torque_unit', 'torque_eng_sp_val', 'torque_eng_sp_unit']].head()
# Out:
#                      torque  torque_val torque_unit  torque_eng_sp_val  \
# 0            190Nm@ 2000rpm       190.0          nm             2000.0
# 1       250Nm@ 1500-2500rpm       250.0          nm             2000.0
# 2     12.7@ 2,700(kgm@ rpm)        12.7         kgm             2700.0
# 3  22.4 kgm at 1750-2750rpm        22.4         kgm             2250.0
# 4     11.5@ 4,500(kgm@ rpm)        11.5         kgm             4500.0
#
#   torque_eng_sp_unit
# 0                rpm
# 1                rpm
# 2                rpm
# 3                rpm
# 4                rpm

# %%
torque_cols = ['torque', 'torque_eng_sp']
list_value_counts(df, [col+'_unit' for col in torque_cols])
# Out:
# <======= torque_unit =======>
# nm     7533
# kgm     373
# Name: torque_unit, dtype: int64
#
# <======= torque_eng_sp_unit =======>
# rpm    7872
# Name: torque_eng_sp_unit, dtype: int64

# %%
df.loc[df['torque_unit'] == 'kgm', 'torque_val'] = 9.80665 * df.loc[df['torque_unit'] == 'kgm', 'torque_val']
df.loc[df['torque_unit'] == 'kgm', 'torque_unit'] = 'nm'
list_value_counts(df, ['torque_unit'])
df[['torque', 'torque_val', 'torque_unit', 'torque_eng_sp_val', 'torque_eng_sp_unit']].head()
# Out:
# <======= torque_unit =======>
# nm    7906
# Name: torque_unit, dtype: int64
#                      torque  torque_val torque_unit  torque_eng_sp_val  \
# 0            190Nm@ 2000rpm  190.000000          nm             2000.0
# 1       250Nm@ 1500-2500rpm  250.000000          nm             2000.0
# 2     12.7@ 2,700(kgm@ rpm)  124.544455          nm             2700.0
# 3  22.4 kgm at 1750-2750rpm  219.668960          nm             2250.0
# 4     11.5@ 4,500(kgm@ rpm)  112.776475          nm             4500.0
#
#   torque_eng_sp_unit
# 0                rpm
# 1                rpm
# 2                rpm
# 3                rpm
# 4                rpm

# %%
# dummy column for calling clear_val_unit_cols() function
df['torque_eng_sp'] = np.nan

df = clear_val_unit_cols(df, torque_cols)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               7906 non-null   int64
#  1   selling_price      7906 non-null   int64
#  2   km_driven          7906 non-null   int64
#  3   fuel               7906 non-null   int64
#  4   seller_type        7906 non-null   int64
#  5   transmission       7906 non-null   int64
#  6   owner              7906 non-null   int64
#  7   mileage            7906 non-null   object
#  8   engine             7906 non-null   object
#  9   max_power          7906 non-null   object
#  10  seats              7906 non-null   float64
#  11  torque_nm          7906 non-null   float64
#  12  torque_eng_sp_rpm  7872 non-null   float64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 1.1+ MB

# %%
numeric_columns = ["selling_price", "km_driven"]

# Create a histogram for each column
for column in numeric_columns:
    plt.hist(df[column])
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.title("Histogram of " + column)
    plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.groupby(['engine','mileage'])['selling_price','year'].max()
# Out:
# <ipython-input-39-4ec2de356042>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['engine','mileage'])['selling_price','year'].max()
#                 selling_price  year
# engine mileage
# 1047   24.7            900000  2019
#        27.28           670000  2019
# 1061   14.0            150000  2006
#        16.0            100000  2006
#        16.9            150000  2010
# ...                       ...   ...
# 999    22.0            375000  2017
#        22.5            390000  2020
#        23.0            275000  2018
#        23.01           500000  2019
#        24.04           535000  2018
#
# [689 rows x 2 columns]

# %%
sns.pairplot(data=df, hue="fuel")

# %%
sns.distplot(df['torque_eng_sp_rpm'])
# Out:
# <ipython-input-41-73f5d8cd7a06>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['torque_eng_sp_rpm'])
# <Axes: xlabel='torque_eng_sp_rpm', ylabel='Density'>

# %%
plt.barh(df['fuel'],df['selling_price'])
# Out:
# <BarContainer object of 7906 artists>

# %%
df['owner'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='owner'>

# %%
plt.hist(df.km_driven)
# Out:
# (array([7.835e+03, 6.500e+01, 4.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([1.0000000e+00, 2.3604660e+05, 4.7209220e+05, 7.0813780e+05,
#         9.4418340e+05, 1.1802290e+06, 1.4162746e+06, 1.6523202e+06,
#         1.8883658e+06, 2.1244114e+06, 2.3604570e+06]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x=df['torque_eng_sp_rpm'], y=df['owner'],hue=df['fuel'])
# Out:
# <Axes: xlabel='torque_eng_sp_rpm', ylabel='owner'>

# %%
plt.figure(figsize=(10,15))
sns.heatmap(df.corr()[['selling_price']],annot=True,cmap='coolwarm')
# Out:
# <ipython-input-50-46c64ab12245>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr()[['selling_price']],annot=True,cmap='coolwarm')
# <Axes: >

# %%
df['transmission'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.countplot(df['fuel'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['seller_type'],palette='GnBu')
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(x=df['engine'],y=df['transmission'],hue=df['fuel'])
# Out:
# <Axes: xlabel='engine', ylabel='transmission'>

# %%
df['engine'] = pd.to_numeric(df['engine'])
sns.violinplot(x='torque_nm', y='engine', data=df)
# Out:
# <Axes: xlabel='torque_nm', ylabel='engine'>

# %%
sns.boxplot(df['torque_nm'])
# Out:
# <Axes: >

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='Greys')
# Out:
# <ipython-input-76-ebefe3a0a058>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='Greys')
# <Axes: >

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# year                 0
# selling_price        0
# km_driven            0
# fuel                 0
# seller_type          0
# transmission         0
# owner                0
# mileage              0
# engine               0
# max_power            0
# seats                0
# torque_nm            0
# torque_eng_sp_rpm    0
# dtype: int64

# %% [markdown]
# # Principal Component Analysis

# %%
# Apply PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)  # Choose the number of principal components
principal_components = pca.fit_transform(df)

# Analyze principal components
print("Explained variance:", pca.explained_variance_ratio_)
print("Principal components:\n", pca.components_)

# Visualize data

plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
# Out:
# Explained variance: [0.99504994 0.00494833]
# Principal components:
#  [[ 1.99359847e-06  9.99877458e-01 -1.56509845e-02 -2.35064879e-07
#   -1.78099267e-07 -2.43904002e-07 -3.39756185e-07 -6.32816922e-07
#    2.91365546e-04  3.31015046e-05  6.17901629e-08  6.82744173e-05
#   -1.60172426e-04]
#  [-2.40724230e-05  1.56490598e-02  9.99860819e-01 -5.82098008e-06
#    3.29992302e-07  4.33992172e-07  5.17684053e-06 -1.50324330e-05
#    2.87608077e-03  8.56531770e-05  4.20641957e-06  3.11291048e-04
#   -5.00730165e-03]]

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=3, random_state=42)  # Example with 3 clusters
km
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
km.fit(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
y_predicted = km.predict(df)
y_predicted
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
df['Clusters'] = y_predicted
df.head()
# Out:
#    year  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0  2014         450000     145500     1            1             1      0
# 1  2014         370000     120000     1            1             1      2
# 2  2006         158000     140000     3            1             1      4
# 3  2010         225000     127000     1            1             1      0
# 4  2007         130000     120000     3            1             1      0
#
#   mileage  engine max_power  seats   torque_nm  torque_eng_sp_rpm  Clusters
# 0   23.4     1248       74     5.0  190.000000             2000.0         1
# 1  21.14     1498   103.52     5.0  250.000000             2000.0         1
# 2   17.7     1497       78     5.0  124.544455             2700.0         1
# 3   23.0     1396       90     5.0  219.668960             2250.0         1
# 4   16.1     1298     88.2     5.0  112.776475             4500.0         1

# %%
df['Clusters'].value_counts()
# Out:
# 1    7284
# 0     447
# 2     141
# Name: Clusters, dtype: int64

# %%
df1 = df[df.Clusters==0]
df2 = df[df.Clusters==1]
df3 = df[df.Clusters==3]
plt.scatter(df1['selling_price'],df1['year'],color='green')
plt.scatter(df2['selling_price'],df2['year'],color='red')
plt.scatter(df3['selling_price'],df3['year'],color='black')

# %%
df1 = df[df.Clusters==0]
df2 = df[df.Clusters==1]
df3 = df[df.Clusters==3]
plt.scatter(df1['selling_price'],df1['fuel'],color='green')
plt.scatter(df2['selling_price'],df2['fuel'],color='red')
plt.scatter(df3['selling_price'],df3['fuel'],color='black')

# %%
df1 = df[df.Clusters==0]
df2 = df[df.Clusters==1]
df3 = df[df.Clusters==3]
plt.scatter(df1['km_driven'],df1['torque_nm'],color='green')
plt.scatter(df2['km_driven'],df2['torque_nm'],color='red')
plt.scatter(df3['km_driven'],df3['torque_nm'],color='black')
